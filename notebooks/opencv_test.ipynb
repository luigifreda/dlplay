# %% [markdown]
# **BEFORE STARTING**
# 1) Copy this notebook in your drive and run your copy!
# 2) Check the notebook instance type and set it to *GPU*
# *Runtime->Change runtime type*

# %%
# install opencv 
# !pip install -q -U opencv-python

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# files.upload()  # this can be used to upload files (it will prompt you to select and upload stuff)
# check other useful commands on https://colab.research.google.com/notebooks/io.ipynb 
# !pwd

# %% [markdown]
# Download the shared data.zip and uzip it
# The drive *FILE_ID=1DSdm38U7cxUlC6V5r3-dIxGVKk4NRgws*

# %%
import os
# set the file id of your zip from drive file ID 
os.environ['FILE_ID']='1DSdm38U7cxUlC6V5r3-dIxGVKk4NRgws'  
# download your zip 
# !wget --no-check-certificate "https://docs.google.com/uc?export=download&id="$FILE_ID -O data.zip
# unzip the file 
# !unzip data.zip  
#switch to the new folder extracted
os.chdir("/content/")

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# from https://docs.opencv.org/3.0-beta/doc/py_tutorials/py_imgproc/py_canny/py_canny.html#canny


img = cv2.imread('data/messi5.jpg',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
